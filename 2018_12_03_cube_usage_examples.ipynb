# %%
import xarray as xr
ds = xr.open_zarr('/home/jovyan/work/datacube/ESDCv1.0.2_2/esdc-8d-0.25deg-1x720x1440-1.0.2_2.zarr')

# %% [markdown]
# # The ESDC data cube v 1.0.2_2
#
#
# ## Usage
#
#
#
# __Open a Cube (config: 8d, 0.25deg)__

# %%
import xarray as xr
ds = xr.open_zarr('/home/jovyan/work/datacube/ESDCv1.0.2_2/esdc-8d-0.25deg-1x720x1440-1.0.2_2.zarr')
ds
# Out:
# <xarray.Dataset>
# Dimensions:                            (bnds: 2, lat: 720, lon: 1440, time: 1702)
# Coordinates:
#   * lat                                (lat) float32 89.875 89.625 89.375 ...
#     lat_bnds                           (lat, bnds) float32 dask.array<shape=(720, 2), chunksize=(720, 2)>
#   * lon                                (lon) float32 -179.875 -179.625 ...
#     lon_bnds                           (lon, bnds) float32 dask.array<shape=(1440, 2), chunksize=(1440, 2)>
#   * time                               (time) datetime64[ns] 1980-01-05 ...
#     time_bnds                          (time, bnds) datetime64[ns] dask.array<shape=(1702, 2), chunksize=(1702, 2)>
# Dimensions without coordinates: bnds
# Data variables:
#     AOD1600_mean                       (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     AOD550_mean                        (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     AOD670_mean                        (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     AOD870_mean                        (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     Rg                                 (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     aerosol_optical_thickness_1610     (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     aerosol_optical_thickness_550      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     aerosol_optical_thickness_555      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     aerosol_optical_thickness_659      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     aerosol_optical_thickness_865      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     air_temperature_2m                 (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     analysed_sst                       (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     bare_soil_evaporation              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     black_sky_albedo                   (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     black_sky_albedo_avhrr             (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     burnt_area                         (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     c_emissions                        (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     cee                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     cer                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     cfc                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     chlor_a                            (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     cot                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     country_mask                       (time, lat, lon) float64 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     cph                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     cth                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     ctp                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     ctt                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     evaporation                        (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     evaporative_stress                 (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     fapar_tip                          (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     fat_c                              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     fat_p                              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     flt_c                              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     flt_p                              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     fractional_snow_cover              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     free_fat_c                         (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     free_flt_c                         (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     free_lrt_c                         (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     free_msr_flt                       (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     free_msr_lrt                       (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     gross_primary_productivity         (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     interception_loss                  (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     iwp                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     land_surface_temperature           (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     latent_energy                      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     leaf_area_index                    (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     lrt_c                              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     lrt_p                              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     lwp                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     mask                               (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     max_air_temperature_2m             (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     min_air_temperature_2m             (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     msr_flt                            (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     msr_lrt                            (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     net_ecosystem_exchange             (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     net_radiation                      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     nobs                               (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     open_water_evaporation             (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     ozone                              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     par                                (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     pardiff                            (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     potential_evaporation              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     precipitation                      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     precipitation_era5                 (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     psurf                              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     root_moisture                      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     sea_ice_fraction                   (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     sensible_heat                      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     snow_sublimation                   (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     snow_water_equivalent              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     soil_moisture                      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     srex_mask                          (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     stemp                              (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     surface_moisture                   (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     terrestrial_ecosystem_respiration  (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     totcol_assim                       (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     totcol_free                        (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     totcol_msr                         (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     transpiration                      (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     water_mask                         (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     water_vapour                       (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     white_sky_albedo                   (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     white_sky_albedo_avhrr             (time, lat, lon) float32 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     xch4                               (time, lat, lon) float64 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>
#     xco2                               (time, lat, lon) float64 dask.array<shape=(1702, 720, 1440), chunksize=(1, 720, 1440)>

# %% [markdown]
# __Open a variable (e.g. par)__

# %%
ds.par
# Out:
# <xarray.DataArray 'par' (time: 1702, lat: 720, lon: 1440)>
# dask.array<shape=(1702, 720, 1440), dtype=float32, chunksize=(1, 720, 1440)>
# Coordinates:
#   * lat      (lat) float32 89.875 89.625 89.375 89.125 88.875 88.625 88.375 ...
#   * lon      (lon) float32 -179.875 -179.625 -179.375 -179.125 -178.875 ...
#   * time     (time) datetime64[ns] 1980-01-05 1980-01-13 1980-01-21 ...
# Attributes:
#     long_name:      Photosynthetically active radiation
#     project_name:   BESS
#     references:     Ryu, Y.*, Jiang, C., Kobayashi, H., & Detto, M. (2018). M...
#     source_name:    surface_downwelling_photosynthetic_radiative_flux_in_air
#     standard_name:  surface_downwelling_photosynthetic_radiative_flux_in_air
#     units:          W m-2
#     url:            http://environment.snu.ac.kr/bess_rad/

# %% [markdown]
# __Plot a time step__

# %%
v = ds.par.sel(time='2003-01-05')
v.plot()

# %% [markdown]
# __Plot a regional subset__:

# %%
v = ds.par.loc[dict(lat=slice(40, -20), lon=slice(-20, 20), time='2003-01-05')]
v.plot()

# %% [markdown]
# __Plot a time step close to your choice__

# %%
v = ds.par.sel(time='2003-01-08', method='nearest')
v.plot()

# %% [markdown]
# __Plot a time series for a particular location__

# %%
v = ds.par.sel(dict(lat=50, lon=10), method='nearest')
v.plot()
